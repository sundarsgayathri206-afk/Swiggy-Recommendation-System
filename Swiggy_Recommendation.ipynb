# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import TargetEncoder, StandardScaler,OneHotEncoder
from sklearn.cluster import KMeans
from category_encoders import TargetEncoder

# %%
# 1. Load Dataset
df = pd.read_csv('swiggy.csv')

# %%
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine          lic_no  \
# ...

# %%
# 2. Data Cleaning
# Identify and drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine          lic_no  \
# ...

# %%
df.isna().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
df.dropna(subset=['city', 'cuisine', 'rating', 'cost'], inplace=True)

# %%
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine          lic_no  \
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148393  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148394  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148395  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148396  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148397  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine          lic_no  \
# ...

# %%
# 2. Handle Non-Numeric Values and Impute (Prevents Empty DF) [Source 3]
# We convert columns to numeric first so '--' becomes NaN, then fill those NaNs
for col in ['rating', 'cost', 'rating_count']:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    # Use median for rating and cost, 0 for rating_count [Source 3]
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val if pd.notna(median_val) else 0)

# Fill Categorical missing values with a placeholder
df[['city', 'cuisine']] = df[['city', 'cuisine']].fillna('Unknown')

# 3. Target Encoding [Requested feature]
# We encode based on the now-cleaned 'rating' column
encoder = TargetEncoder(cols=['city', 'cuisine'])
encoded_cols = encoder.fit_transform(df[['city', 'cuisine']], df['rating'])

# 4. Final Feature Preparation (X)
# Combine encoded categorical columns with the cleaned numerical columns
X = pd.concat([encoded_cols, df[['rating', 'cost', 'rating_count']]], axis=1)

# CRITICAL FIX: Ensure X has no remaining NaNs before scaling
X = X.fillna(0) 

# 5. Scaling and Clustering [Source 4]
if not X.empty:
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(X) # This will now succeed
    
    # Apply K-Means
    kmeans = KMeans(n_clusters=8, random_state=42, n_init=10)
    df['cluster'] = kmeans.fit_predict(scaled_data)
    
    # 6. Save and Verify Alignment [Source 4, 7]
    df.to_csv('cleaned_data.csv', index=False)
    X.to_csv('encoded_data.csv', index=False)
    print(f"Success! Processed {len(df)} restaurants into {df['cluster'].nunique()} clusters.")
else:
    print("Error: Dataframe is empty. Please check the source data quality.")
# Out:
# c:\Users\sunda\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\sunda\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Success! Processed 148398 restaurants into 8 clusters.

# %%
# Save the mapping (encoder) for the Streamlit app [2, 6]
with open('target_mappings.pkl', 'wb') as f:
    pickle.dump({'city': city_map, 'cuisine': cuisine_map}, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Save the mapping (encoder) for the Streamlit app [2, 6]
#       2 with open('target_mappings.pkl', 'wb') as f:
# ----> 3     pickle.dump({'city': city_map, 'cuisine': cuisine_map}, f)
#
# NameError: name 'city_map' is not defined

# %%
# Save processed data and model
df.to_csv('encoded_data.csv', index=False) # [2, 3]
with open('kmeans_model.pkl', 'wb') as f:
    pickle.dump(kmeans, f)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("Preprocessing and Training Complete!")
# Out:
# Preprocessing and Training Complete!
